# %%
import numpy as np
import torch

from utils.mnist_loader import MNISTLoader
from models.vanilla_gan import VanillaGAN

# %%
loader = MNISTLoader()

model = VanillaGAN(loader.feature_depth, 100)

# %%
model.discriminator(torch.tensor(loader.train_features[0]).float())
# Out:
# tensor([0.4926], grad_fn=<SigmoidBackward>)

# %%
model.generator(torch.tensor(np.random.normal(size=[100])).float())
# Out:
# tensor([-1.3940e-03,  4.7189e-02, -7.2002e-04,  3.8286e-03, -2.9560e-04,
#          2.6506e-02,  6.9684e-02, -1.0549e-04, -6.5759e-04,  1.6536e-01,
#          4.4716e-02,  6.4198e-02, -1.3021e-03,  2.1690e-02, -1.7490e-03,
#          1.7611e-02, -2.2806e-03, -7.4352e-04,  1.8919e-02, -1.6366e-03,
#         -1.1039e-03, -1.0153e-04,  4.6893e-02, -1.3758e-03,  2.4211e-01,
#          7.6863e-02,  1.4539e-02,  5.5081e-02, -1.0290e-03,  3.2231e-02,
#         -7.4307e-04, -9.1493e-04,  3.1718e-03, -2.4545e-03, -1.2228e-03,
#         -2.3845e-04, -3.0346e-04,  2.1625e-01, -1.0076e-04, -1.2987e-03,
#          8.7387e-02,  2.6041e-02, -3.7513e-04, -9.7418e-04, -1.3797e-03,
#          6.4578e-02,  1.9885e-02,  8.6183e-02,  1.2493e-01,  1.6948e-01,
#          7.4615e-03, -5.1634e-04, -1.3184e-03, -1.4325e-03,  1.1414e-01,
#         -1.9972e-03,  2.8066e-02, -1.0690e-03, -1.0202e-03, -4.3676e-05,
#          1.7853e-03,  1.7370e-02,  1.2916e-01,  9.4679e-03,  8.5327e-02,
# ...
